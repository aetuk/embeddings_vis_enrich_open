# %%
import urllib.request, json, os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

try:
    url = os.environ.get("AZURE_URL")

    hdr ={
    # Request headers
    'x-service-line': 'cxm',
    'x-brand': 'dentsu',
    'x-project': 'test1',
    'Content-Type': 'application/json',
    'Cache-Control': 'no-cache',
    'api-version': 'v15',
    'Ocp-Apim-Subscription-Key': os.environ.get("OPENAI_API_KEY"),
    }

    # Request body
    data = {"input": "Hello this is a test", "user": "string", "input_type": "query","encoding_format": "float","dimensions": 1}
    data = json.dumps(data)
    req = urllib.request.Request(url, headers=hdr, data = bytes(data.encode("utf-8")))

    req.get_method = lambda: 'POST'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
# Out:
# 200
# b'{\n  "object": "list",\n  "data": [\n    {\n      "object": "embedding",\n      "index": 0,\n      "embedding": [\n        -0.017483747,\n        0.0026926377,\n        -0.020222781,\n        -0.025406469,\n        -0.017368553,\n        0.025585657,\n        -0.02090114,\n        -0.0016239021,\n        -0.01309361,\n        -0.018802065,\n        0.020645155,\n        0.0036445803,\n        -0.026315214,\n        -0.005542066,\n        0.0072763613,\n        -0.0076539386,\n        0.022603437,\n        -0.0064444114,\n        0.0006987579,\n        -0.000846349,\n        -0.013797568,\n        -0.0017534943,\n        0.0016974977,\n        0.012376853,\n        -0.027185561,\n        -0.025419267,\n        0.0029406226,\n        -0.040547956,\n        0.023601776,\n        -0.0141431475,\n        0.006230024,\n        -0.002039877,\n        -0.004713316,\n        -0.028798264,\n        -0.00066915964,\n        -0.01343919,\n        -0.004662119,\n        -0.016306216,\n        0.01939083,\n        -0.009855405,\n        0.01442473,\n        0.011461709,\n        0.008255502,\n        -0.016664594,\n        -0.0056412597,\n        0.0054172734,\n        0.01578145,\n        -0.023512183,\n        0.0017950918,\n        0.03530027,\n        0.035863437,\n        -0.005983639,\n        -0.02787672,\n        -0.0014471128,\n        0.0026990373,\n        0.015026294,\n        0.0068411874,\n        0.025227278,\n        0.0025470464,\n        -0.010412172,\n        -0.024126545,\n        -0.00065556046,\n        0.0020638756,\n        0.006290821,\n        0.00480611,\n        0.005158089,\n        0.016383013,\n        0.009343437,\n        -0.006719595,\n        0.010956139,\n        0.020529961,\n        0.0012191265,\n        0.006009238,\n        -0.015461468,\n        0.017317357,\n        0.001194328,\n        -0.0154870665,\n        0.0067259944,\n        0.0060604345,\n        -0.008249102,\n        0.018840464,\n        -0.026046429,\n        -0.010757752,\n        0.018366892,\n        0.0119224815,\n        -0.00047037163,\n        -0.009055454,\n        0.023691371,\n        -0.017010175,\n        -0.027825521,\n        -0.009157848,\n        0.014450328,\n        0.014040753,\n        0.018136507,\n        -0.026289614,\n        0.015359074,\n        -0.005074894,\n        0.031588495,\n        -0.013010415,\n        -0.014002356,\n        -0.003052616,\n        -0.0035549856,\n        0.012146467,\n        -0.00862028,\n        -0.01907085,\n        -0.004079754,\n        -0.011186525,\n        0.0008759472,\n        0.027262356,\n        0.008057114,\n        0.006031636,\n        0.021861082,\n        -0.0055356664,\n        -0.027953515,\n        -0.00043197395,\n        0.011295319,\n        -0.011340116,\n        -0.01873807,\n        -0.022513842,\n        -0.00862028,\n        0.0005551665,\n        0.029873399,\n        0.022437047,\n        -0.007244363,\n        0.016165426,\n        0.005836448,\n        -0.010661758,\n        -0.025816044,\n        0.004591723,\n        -0.0010623359,\n        0.026750388,\n        -0.0071483687,\n        0.0021758687,\n        0.016319016,\n        -0.02966861,\n        0.018008513,\n        -0.018610077,\n        0.02138751,\n        -0.02335859,\n        -0.004034957,\n        -0.014002356,\n        0.025969634,\n        0.00547167,\n        -0.003219006,\n        -0.010712954,\n        0.0089914575,\n        0.0073211584,\n        -0.018302897,\n        0.014655116,\n        -0.010546564,\n        -0.008025116,\n        0.007711535,\n        0.023332993,\n        -0.0068923845,\n        0.032074865,\n        0.032100465,\n        0.0020622755,\n        0.012524045,\n        -0.005702056,\n        -0.021771487,\n        -0.006233224,\n        0.0070779733,\n        0.0040605552,\n        -0.02372977,\n        0.014463128,\n        0.04231425,\n        0.007282761,\n        0.006764392,\n        -0.011480908,\n        -0.008575483,\n        -0.025483264,\n         ...
